# %%
import pandas as pd
from sqlalchemy import create_engine
import os

# %% [markdown]
# ### Store CSV into DataFrame

# %%
res_file_1= os.path.join("Data","ReservationData1.csv")
res_data_1_df = pd.read_csv(res_file_1)
res_data_1_df
# Out:
#         OrderNumber                           Park  \
# 0        2-32735678          SADDLEHORN CAMPGROUND
# 1        2-32734735  BLANCO RIVER GROUP CAMPGROUND
# 2        2-32736183            CUTTHROAT BAY GROUP
# 3        2-32734610         Pinon Flats Campground
# 4        2-32737179          SADDLEHORN CAMPGROUND
# ...             ...                            ...
# 1048570         NaN                            NaN
# 1048571         NaN                            NaN
# 1048572         NaN                            NaN
# 1048573         NaN                            NaN
# 1048574         NaN                            NaN
#
#                                  SiteType  FacilityID FacilityState  \
# 0                    STANDARD NONELECTRIC    234778.0            CO
# 1              GROUP STANDARD NONELECTRIC    233318.0            CO
# 2              GROUP STANDARD NONELECTRIC    233880.0            CO
# 3        GROUP TENT ONLY AREA NONELECTRIC    234685.0            CO
# ...

# %%
res_file_2= os.path.join("Data","ReservationData2.csv")
res_data_2_df = pd.read_csv(res_file_2)
res_data_2_df.head()
# Out:
#   OrderNumber                               Park  \
# 0  2-29871859                     SPRINGER GULCH
# 1  2-29871867  Pinyon  (Pi̱on) Flats Campground
# 2  2-29872914           BELLAIRE LAKE CAMPGROUND
# 3  2-29870963                      MOUNTAIN PARK
# 4  2-29870966                         MATTERHORN
#
#                            SiteType  FacilityID FacilityState   StartDate  \
# 0              STANDARD NONELECTRIC      233718            CO    9/7/2014
# 1  GROUP TENT ONLY AREA NONELECTRIC      234685            CO  10/10/2014
# 2                 STANDARD ELECTRIC      233137            CO   8/30/2014
# 3   GROUP STANDARD AREA NONELECTRIC      231852            CO    8/7/2015
# 4              STANDARD NONELECTRIC      233902            CO   8/28/2014
#
#       EndDate  NumberOfPeople
# 0    9/9/2014               2
# 1  10/12/2014              30
# 2    9/1/2014               4
# 3   8/10/2015              31
# 4   8/29/2014               2

# %%
import dask.dataframe as dd

df_1=dd.from_pandas(res_data_1_df,npartitions=3)

# %%
df_1.head(5)
# Out:
#   OrderNumber                           Park  \
# 0  2-32735678          SADDLEHORN CAMPGROUND
# 1  2-32734735  BLANCO RIVER GROUP CAMPGROUND
# 2  2-32736183            CUTTHROAT BAY GROUP
# 3  2-32734610         Pinon Flats Campground
# 4  2-32737179          SADDLEHORN CAMPGROUND
#
#                            SiteType  FacilityID FacilityState   StartDate  \
# 0              STANDARD NONELECTRIC    234778.0            CO   10/9/2015
# 1        GROUP STANDARD NONELECTRIC    233318.0            CO    7/7/2016
# 2        GROUP STANDARD NONELECTRIC    233880.0            CO   7/15/2016
# 3  GROUP TENT ONLY AREA NONELECTRIC    234685.0            CO  10/23/2015
# 4              STANDARD NONELECTRIC    234778.0            CO   10/3/2015
#
#       EndDate  NumberOfPeople
# 0  10/11/2015               1
# 1   7/10/2016              75
# 2   7/17/2016              30
# 3  10/25/2015              20
# 4   10/4/2015               2

# %%
df_2=df.append(res_data_2_df)

# %%
df_2
# Out:
# Dask DataFrame Structure:
#               OrderNumber    Park SiteType FacilityID FacilityState StartDate EndDate NumberOfPeople
# npartitions=4
#                    object  object   object    float64        object    object  object          int64
#                       ...     ...      ...        ...           ...       ...     ...            ...
#                       ...     ...      ...        ...           ...       ...     ...            ...
#                       ...     ...      ...        ...           ...       ...     ...            ...
#                       ...     ...      ...        ...           ...       ...     ...            ...
# Dask Name: concat, 12 tasks

# %%
df=df_2.compute()

# %%
df
# Out:
#        OrderNumber                           Park  \
# 0       2-32735678          SADDLEHORN CAMPGROUND
# 1       2-32734735  BLANCO RIVER GROUP CAMPGROUND
# 2       2-32736183            CUTTHROAT BAY GROUP
# 3       2-32734610         Pinon Flats Campground
# 4       2-32737179          SADDLEHORN CAMPGROUND
# ...            ...                            ...
# 186417  2-32660704          GORE CREEK CAMPGROUND
# 186418  2-32656250                  ROBERTS CABIN
# 186419  2-32657290        MORAINE PARK CAMPGROUND
# 186420  2-32657310                 SPRINGER GULCH
# 186421  2-32657321           DIFFICULT CAMPGROUND
#
#                                 SiteType  FacilityID FacilityState  \
# 0                   STANDARD NONELECTRIC    234778.0            CO
# 1             GROUP STANDARD NONELECTRIC    233318.0            CO
# 2             GROUP STANDARD NONELECTRIC    233880.0            CO
# 3       GROUP TENT ONLY AREA NONELECTRIC    234685.0            CO
# ...

# %% [markdown]
# ### Store CSV into DataFrame

# %%
rds_connection_string = "<postgres>:<postgres>@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')
