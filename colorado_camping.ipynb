# %%
import pandas as pd
from sqlalchemy import create_engine
import os

# %% [markdown]
# # Store CSV into DataFrame

# %% [markdown]
# ## Reservation Data 2010 - 2015

# %%
res_file_10_15= os.path.join("Data","ReservationData10_15.csv")
res_data_10_15_df = pd.read_csv(res_file_10_15)
res_data_10_15_df
# Out:
#        OrderNumber                          Park  \
# 0       2-13888626      GLACIER BASIN CAMPGROUND
# 1       2-13883425  BOGAN FLATS CAMPGROUND GRP S
# 2       2-13884441      BELLAIRE LAKE CAMPGROUND
# 3       2-13887874      GLACIER BASIN CAMPGROUND
# 4       2-13887885            BUFFALO CAMPGROUND
# ...            ...                           ...
# 472744  2-32660704         GORE CREEK CAMPGROUND
# 472745  2-32656250                 ROBERTS CABIN
# 472746  2-32657290       MORAINE PARK CAMPGROUND
# 472747  2-32657310                SPRINGER GULCH
# 472748  2-32657321          DIFFICULT CAMPGROUND
#
#                                 SiteType  FacilityID FacilityState  StartDate  \
# 0       GROUP TENT ONLY AREA NONELECTRIC      232462            CO  8/12/2010
# 1                   STANDARD NONELECTRIC      232158            CO   9/3/2010
# 2                      STANDARD ELECTRIC      233137            CO  8/24/2010
# 3                   STANDARD NONELECTRIC      232462            CO   8/7/2010
# 4                   STANDARD NONELECTRIC      231875            CO  8/13/2010
# ...                                  ...         ...           ...        ...
# 472744             TENT ONLY NONELECTRIC      234794            CO  9/18/2015
# 472745                 CABIN NONELECTRIC      233808            CO  10/6/2015
# 472746                           WALK TO      232463            CO  9/13/2015
# 472747              STANDARD NONELECTRIC      233718            CO  9/18/2015
# 472748              STANDARD NONELECTRIC      231880            CO  9/20/2015
#
#           EndDate  NumberOfPeople
# 0       8/13/2010              17
# 1        9/6/2010               6
# 2       8/27/2010               2
# 3        8/8/2010               1
# 4       8/15/2010               6
# ...           ...             ...
# 472744  9/20/2015               2
# 472745  10/9/2015               2
# 472746  9/16/2015               1
# 472747  9/21/2015               4
# 472748  9/24/2015               2
#
# [472749 rows x 8 columns]

# %% [markdown]
# ## Reservation Data 2010 - 2015

# %%
res_file_16_20= os.path.join("Data","ReservationData16_20.csv")
res_data_16_20_df = pd.read_csv(res_file_16_20)
res_data_16_20_df
# Out:
#          OrderNumber                           Park  \
# 0         2-32735678          SADDLEHORN CAMPGROUND
# 1         2-32734735  BLANCO RIVER GROUP CAMPGROUND
# 2         2-32736183            CUTTHROAT BAY GROUP
# 3         2-32734610         Pinon Flats Campground
# 4         2-32737179          SADDLEHORN CAMPGROUND
# ...              ...                            ...
# 701027  0299021752-1  BUCKEYE RECREATION AREA (CO)
# 701028  0299110351-1  BUCKEYE RECREATION AREA (CO)
# 701029  0299113958-1  BUCKEYE RECREATION AREA (CO)
# 701030  0299604686-1  BUCKEYE RECREATION AREA (CO)
# 701031  0299699639-1  BUCKEYE RECREATION AREA (CO)
#
#                                 SiteType  FacilityID FacilityState  \
# 0                   STANDARD NONELECTRIC      234778            CO
# 1             GROUP STANDARD NONELECTRIC      233318            CO
# 2             GROUP STANDARD NONELECTRIC      233880            CO
# 3       GROUP TENT ONLY AREA NONELECTRIC      234685            CO
# 4                   STANDARD NONELECTRIC      234778            CO
# ...                                  ...         ...           ...
# 701027              STANDARD NONELECTRIC      234724            CO
# 701028              STANDARD NONELECTRIC      234724            CO
# 701029              STANDARD NONELECTRIC      234724            CO
# 701030   GROUP STANDARD AREA NONELECTRIC      234724            CO
# 701031              STANDARD NONELECTRIC      234724            CO
#
#          StartDate     EndDate  NumberOfPeople
# 0        10/9/2015  10/11/2015               1
# 1         7/7/2016   7/10/2016              75
# 2        7/15/2016   7/17/2016              30
# 3       10/23/2015  10/25/2015              20
# 4        10/3/2015   10/4/2015               2
# ...            ...         ...             ...
# 701027   7/24/2020   7/26/2020               4
# 701028   7/21/2020   7/22/2020               1
# 701029   5/25/2020   5/26/2020               2
# 701030   7/17/2020   7/19/2020              25
# 701031   9/20/2020   9/22/2020               1
#
# [701032 rows x 8 columns]

# %% [markdown]
# ## National Park Data

# %%
nps_file= os.path.join("Data","NatPark_All_Clean_Summary_Visitor_Use.csv")
nps_df_0 = pd.read_csv(nps_file)

nps_df_1["Recreation_ Visitors"]=nps_df_0["Recreation_ Visitors"].str.replace(",","")
nps_df_1["Non_Recreation_Visitors"]=nps_df_0["Non_Recreation_Visitors"].str.replace(",","")
nps_df_1["Recreation_Visitor_Hours"]=nps_df_0["Recreation_Visitor_Hours"].str.replace(",","")
nps_df_1["Non_Recreation_Hours"]=nps_df_0["Non_Recreation_Hours"].str.replace(",","")
nps_df_1["Concession_Lodging"]=nps_df_0["Concession_Lodging"].str.replace(",","")
nps_df_1["Tent_Campers"]=nps_df_0["Tent_Campers"].str.replace(",","")
nps_df_1["RV_Campers"]=nps_df_0["RV_Campers"].str.replace(",","")
nps_df_1["Backcountry_Campers"]=nps_df_0["Backcountry_Campers"].str.replace(",","")
nps_df_1["Misc_Campers"]=nps_df_0["Misc_Campers"].str.replace(",","")
nps_df_1["Total_Overnight_Stays"]=nps_df_0["Total_Overnight_Stays"].str.replace(",","")

# nps_df_0.dtypes
nps_df_1

data_dict={"Park": object,
           "State": object,
           "Year": int,
           "Month": object,
           "Recreation_ Visitors": int,
           "Non_Recreation_Visitors": int,
           "Recreation_Visitor_Hours": int,
           "Non_Recreation_Hours": int,
           "Concession_Lodging": int,
           "Tent_Campers": int,
           "RV_Campers": int,
           "Backcountry_Campers": int,
           "Misc_Campers": int,
           "Total_Overnight_Stays": int
          }
nps_df=nps_df_1.astype(data_dict)

# %% [markdown]
# # Store DataFrame into PostgresSQL Database

# %% [markdown]
# ## Reservation DataFrame to Database

# %%
rds_connection_string = (f'postgres:postgres@localhost:5432/colorado_camping_db')
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['reservations', 'nps_summary']

# %% [markdown]
# ### 2010 to 2015 Reservation Data

# %%
res_data_10_15_df.to_sql(name='reservations', con=engine, if_exists='append', index=False)

# %%
# import math
# batch_size=100000
# beg=0
# end=beg+batch_size
# for i in range(math.floor(len(res_df)/batch_size)): 
#     print(f'{beg} - {end}')
#     res_df.iloc[beg:end].to_sql(name='reservations', con=engine, if_exists='append', index=False)
#     beg=end
#     end=beg+batch_size
# res_df.iloc[end:].to_sql(name='reservations', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### 2016 to 2020 Reservation Data

# %%
res_data_16_20_df.to_sql(name='reservations', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## National Parks DataFrame to Database

# %%
nps_df.to_sql(name='nps_summary', con=engine, if_exists='append', index=False)
